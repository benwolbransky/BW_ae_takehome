# %%
import sqlite3
import pandas as pd
from glob import glob
import sys
sys.path.append('/Users/benwolbransky/Downloads/BW_ae_takehome/')
from sample_helpers.sample_sql import sample_Tables

# %%
c = sample_Tables(db_path='/Users/benwolbransky/Downloads/BW_ae_takehome/Database/sample.db',csv_path='/Users/benwolbransky/Downloads/BW_ae_takehome/CSV_data')

# %%
c.build_dbs()
# Out:
# USER INPUT REQUIRED:
#  It looks like the database has already populated!
#  Would you like to truncate the tables and rebuild the Database?
#  Please input YES or NO and hit ENTER.
# Tables built successfully!

# %%
c._truncate_tables()

# %%
c.build_dbs()

# %%
c.query('SELECT * from customer_offer_redemptions;')
# Out:
# [(692578410, 19955759064, 1, 1, 1.0, '2021-03-22 08:32:25.000'),
#  (692578464, 19953199999, 1, None, 0.25, '2021-03-22 08:33:04.000'),
#  (692578465, 19953205895, 1, None, 0.25, '2021-03-22 08:33:04.000'),
#  (692578323, 19958677654, None, 1, None, '2021-03-22 08:31:14.000'),
#  (692578412, 19955758949, 1, 1, 2.25, '2021-03-22 08:32:26.000'),
#  (692578415, 19955784767, 3, 3, 1.75, '2021-03-22 08:32:26.000'),
#  (692578179, 19959284467, 1, 1, 0.5, '2021-03-22 08:29:04.000'),
#  (692578407, 19955751174, 2, 2, 1.0, '2021-03-22 08:32:25.000'),
#  (692578645, 19959285590, 1, 1, 0.5, '2021-03-22 08:35:07.000'),
#  (692578831, 19959286037, 0, 2, 2.75, '2021-03-22 08:37:13.000'),
#  (692579690, 19959281701, 1, 1, 0.5, '2021-03-22 08:46:19.000'),
#  (692578405, 19955759671, 1, 1, 1.0, '2021-03-22 08:32:25.000'),
#  (692578409, 19955759123, 1, 1, 3.0, '2021-03-22 08:32:25.000'),
#  (692578414, 19955758966, 1, 1, 2.25, '2021-03-22 08:32:26.000'),
# ...
